# %%
import numpy as np
big_array = np.arange(1_000_000)
# %timeit [x * 2 for x in big_array]
# %timeit big_array * 2
# Out:
# 72.3 ms ± 2.03 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 1.68 ms ± 35.2 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
import pandas as pd
df = pd.read_csv("../data/raw/starter_data.csv")

# %%
df.head()
# Out:
#   category  value        date
# 0        A     10  2025-08-01
# 1        B     15  2025-08-02
# 2        A     12  2025-08-03
# 3        B     18  2025-08-04
# 4        C     25  2025-08-05

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   category  10 non-null     str
#  1   value     10 non-null     int64
#  2   date      10 non-null     str
# dtypes: int64(1), str(2)
# memory usage: 372.0 bytes

# %%
summary = df.describe()

# %%
df.groupby("category")["value"].agg(["count", "mean", "min", "max"])
# Out:
#           count       mean  min  max
# category
# A             4  11.500000   10   13
# B             3  15.666667   14   18
# C             3  27.666667   25   30

# %%
summary.to_csv("../data/processed/summary.csv")

# %%
import matplotlib.pyplot as plt

grouped_mean = df.groupby("category")["value"].mean()
grouped_mean.plot(kind="bar")

plt.savefig("../data/processed/value_by_category.png")

# %%
def get_summary_stats(df):
    return df.describe()
get_summary_stats(df)
# Out:
#            value
# count  10.000000
# mean   17.600000
# std     7.381659
# min    10.000000
# 25%    12.250000
# 50%    14.500000
# 75%    23.250000
# max    30.000000

# %%
import sys
sys.path.append("..")
from src.utils import get_summary_stats
get_summary_stats(df)
# Out:
#            value
# count  10.000000
# mean   17.600000
# std     7.381659
# min    10.000000
# 25%    12.250000
# 50%    14.500000
# 75%    23.250000
# max    30.000000
